# %%
import numpy as np
print("Hello ML")
# Out:
# The kernel failed to start as the Python Environment 'Python 3.7.4' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
